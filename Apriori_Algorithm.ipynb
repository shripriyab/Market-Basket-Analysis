# %% [markdown]
# # Apriori Algorithm for Frequent Item Set Mining and Association Rule Learning

# %% [markdown]
# ### Dataset Name : Grocery Dataset
# ### Number of transactions : 7501
#
# This dataset consists of the various transactions made at a grocery store by different customers.We are applying the apriori algorithm to find the frequent dataset and association rules so as to place the items frequently purchased together.

# %%
import csv
import itertools
from itertools import combinations

# %%
DataFile = open('store_data.csv', 'r')
minsup = 0.01
f2 = "Rules.txt"
f1 = "FItems.txt"
minconf = 0.39

# %% [markdown]
# ## Function to frequency of individual items
# In this function we find the frequency values for each product and eliminate those which have support less than the specified value.

# %%
def L1():

    #Get all 1-itemsets in the list items and their counts in the dictionary counts
    DataCaptured = csv.reader(DataFile, delimiter=',')
    data = list(DataCaptured)
    for e in data:
        e = sorted(e)
    count = {}
    for items in data:
        for item in items:
            if item not in count:
                count[(item)] = 1
            else:
                count[(item)] = count[(item)] + 1
    print("C1 Items", count)
    print("C1 Length : ", len(count))
    print()

    #Check for minSupport
    count2 = {k: v for k, v in count.items() if v >= minsup*7501}
    print("L1 Items : ", count2)
    print("L1 Length : ", len(count2))
    print()

    return count2, data

# %% [markdown]
# ## Generates the various combinations of items
#  This function finds the combinations of items.

# %%
def generateCk(Lk_1, flag, data):
    
    Ck = []

    if flag == 1:
        flag = 0
        Ck=list(itertools.combinations(Lk_1,2))
        print()

    else:
        for item in Lk_1:
            k=len(item)
        unique_list = []
        for i in Lk_1:
            for j in i:
                if j not in unique_list:
                    unique_list.append(j)
        Ck = list(itertools.combinations(unique_list,k+1))
        print()
        
    L = generateLk(set(Ck), data)
    return L, flag

# %% [markdown]
# ## Check minSupport
#
# This function checks the support value of the combinations generated in the previous function.

# %%
def generateLk(Ck, data):
    
    count = {}
    for itemset in Ck:
        #print(itemset)
        i = len(itemset)
        for transaction in data:
            if all(e in transaction for e in itemset):
                if itemset not in count:
                    count[itemset] = 1
                else:
                    count[itemset] = count[itemset] + 1
        
            
    count2 = {k: v for k, v in count.items() if v >= minsup*7501}
    
    
    print("C" + str(i) +" Items : ", count)
    print("C" + str(i) +" Length : ", len(count))
    print()
    
    print("L" + str(i) +" Items : ", count2)
    print("L" + str(i) + " Length : ", len(count2))
    print()
    return count2

# %% [markdown]
# ## Generates association rules
#
# This function generates association rules for the frequent itemset.

# %%
def rulegenerator(fitems):
    
    counter = 0 #number of rules
    for itemset in fitems.keys():
        if isinstance(itemset, str):
            continue
        length = len(itemset)

        union_support = fitems[tuple(itemset)]#the freq of all items together
        for i in range(1, length):

            lefts = map(list, itertools.combinations(itemset, i))
            for left in lefts:
                if len(left) == 1:
                    if ''.join(left) in fitems:
                        leftcount = fitems[''.join(left)]
                        
                        conf = union_support / leftcount
                else:
                    if tuple(left) in fitems:
                        leftcount = fitems[tuple(left)]
                        conf = union_support / leftcount
                if conf >= minconf:
                    fo = open(f2, "a+")
                    right = list(itemset[:])
                    for e in left:
                        right.remove(e)
                    fo.write(str(left) + ' (' + str(leftcount) + ')' + ' -> ' + str(right) + ' (' + str(fitems[''.join(right)]) + ')' + ' [' + str(conf) + ']' + '\n')
                    print(str(left) + ' -> ' + str(right) + ' (' + str(conf) + ')')
                    counter = counter + 1
                    
                    fo.close()
                    
    print(counter, "Rules generated")

# %% [markdown]
# ## Apriori function
#
# Calls the other functions to generate the required output.

# %%
def apriori():
    
    L, data = L1()
    flag = 1 #to generate C2
    FreqItems = dict(L)
    while(len(L) != 0):
        fo = open(f1, "a+")
        for k, v in L.items():
            fo.write(str(k) + ' >>> ' + str(v) + '\n\n')
        fo.close()

        L, flag = generateCk(L, flag, data)
        FreqItems.update(L)
        
    rulegenerator(FreqItems)

# %%
if __name__ == '__main__':
    apriori()
# Out:
# C1 Items {'shrimp': 536, 'almonds': 153, 'avocado': 250, 'vegetables mix': 193, 'green grapes': 68, 'whole weat flour': 70, 'yams': 86, 'cottage cheese': 239, 'energy drink': 200, 'tomato juice': 228, 'low fat yogurt': 574, 'green tea': 991, 'honey': 356, 'salad': 37, 'mineral water': 1788, 'salmon': 319, 'antioxydant juice': 67, 'frozen smoothie': 475, 'spinach': 53, 'olive oil': 494, 'burgers': 654, 'meatballs': 157, 'eggs': 1348, 'chutney': 31, 'turkey': 469, 'milk': 972, 'energy bar': 203, 'whole wheat rice': 439, 'whole wheat pasta': 221, 'french fries': 1282, 'soup': 379, 'light cream': 117, 'shallot': 58, 'frozen vegetables': 715, 'spaghetti': 1306, 'pet food': 49, 'cookies': 603, 'cooking oil': 383, 'champagne': 351, 'chocolate': 1230, 'chicken': 450, 'oil': 173, 'fresh tuna': 167, 'tomatoes': 513, 'black tea': 107, 'extra dark chocolate': 90, 'protein bar': 139, 'red wine': 211, 'pasta': 118, 'pepper': 199, 'shampoo': 37, 'rice': 141, 'sparkling water': 47, 'ham': 203, 'body spray': 86, 'pancakes': 713, 'grated cheese': 393, 'white wine': 124, 'toothpaste': 61, 'parmesan cheese': 149, 'fresh bread': 323, 'ground beef': 737, 'escalope': 595, 'herb & pepper': 371, 'tomato sauce': 106, 'magazines': 82, 'strawberries': 160, 'strong cheese': 58, 'pickles': 45, 'cake': 608, 'hot dogs': 243, 'brownies': 253, 'cereals': 193, 'clothes accessories': 63, 'bug spray': 65, 'muffins': 181, 'light mayo': 204, 'gums': 101, 'soda': 47, 'cider': 79, 'corn': 36, 'yogurt cake': 205, 'mint': 131, 'butter': 226, 'asparagus': 35, 'french wine': 169, 'salt': 69, 'tea': 29, 'barbecue sauce': 81, 'mayonnaise': 46, 'zucchini': 71, 'carrots': 115, 'mushroom cream sauce': 143, 'candy bars': 73, 'chili': 46, 'mashed potato': 31, 'nonfat milk': 78, 'water spray': 3, 'chocolate bread': 32, 'mint green tea': 42, 'eggplant': 99, 'blueberries': 69, 'bacon': 65, 'fromage blanc': 102, 'gluten free bar': 52, 'dessert wine': 33, 'flax seed': 68, 'hand protein bar': 39, 'sandwich': 34, 'babies food': 34, 'melons': 90, 'cauliflower': 36, 'green beans': 65, 'ketchup': 33, 'bramble': 14, 'burger sauce': 44, 'oatmeal': 33, ' asparagus': 1, 'cream': 7, 'napkins': 5}
# C1 Length :  120
#
# L1 Items :  {'shrimp': 536, 'almonds': 153, 'avocado': 250, 'vegetables mix': 193, 'yams': 86, 'cottage cheese': 239, 'energy drink': 200, 'tomato juice': 228, 'low fat yogurt': 574, 'green tea': 991, 'honey': 356, 'mineral water': 1788, 'salmon': 319, 'frozen smoothie': 475, 'olive oil': 494, 'burgers': 654, 'meatballs': 157, 'eggs': 1348, 'turkey': 469, 'milk': 972, 'energy bar': 203, 'whole wheat rice': 439, 'whole wheat pasta': 221, 'french fries': 1282, 'soup': 379, 'light cream': 117, 'frozen vegetables': 715, 'spaghetti': 1306, 'cookies': 603, 'cooking oil': 383, 'champagne': 351, 'chocolate': 1230, 'chicken': 450, 'oil': 173, 'fresh tuna': 167, 'tomatoes': 513, 'black tea': 107, 'extra dark chocolate': 90, 'protein bar': 139, 'red wine': 211, 'pasta': 118, 'pepper': 199, 'rice': 141, 'ham': 203, 'body spray': 86, 'pancakes': 713, 'grated cheese': 393, 'white wine': 124, 'parmesan cheese': 149, 'fresh bread': 323, 'ground beef': 737, 'escalope': 595, 'herb & pepper': 371, 'tomato sauce': 106, 'magazines': 82, 'strawberries': 160, 'cake': 608, 'hot dogs': 243, 'brownies': 253, 'cereals': 193, 'muffins': 181, 'light mayo': 204, 'gums': 101, 'cider': 79, 'yogurt cake': 205, 'mint': 131, 'butter': 226, 'french wine': 169, 'barbecue sauce': 81, 'carrots': 115, 'mushroom cream sauce': 143, 'nonfat milk': 78, 'eggplant': 99, 'fromage blanc': 102, 'melons': 90}
# L1 Length :  75
#
#
# C2 Items :  {('tomatoes', 'fromage blanc'): 11, ('salmon', 'black tea'): 10, ('parmesan cheese', 'butter'): 6, ('french fries', 'cereals'): 36, ('pasta', 'white wine'): 5, ('cookies', 'cereals'): 5, ('protein bar', 'nonfat milk'): 1, ('french fries', 'fromage blanc'): 28, ('ground beef', 'mint'): 19, ('honey', 'energy bar'): 10, ('brownies', 'barbecue sauce'): 2, ('soup', 'pepper'): 14, ('eggs', 'cereals'): 28, ('milk', 'soup'): 114, ('meatballs', 'french fries'): 23, ('cereals', 'fromage blanc'): 8, ('soup', 'frozen vegetables'): 60, ('cottage cheese', 'fresh tuna'): 14, ('fresh bread', 'tomato sauce'): 8, ('chocolate', 'mint'): 25, ('almonds', 'turkey'): 9, ('oil', 'nonfat milk'): 1, ('grated cheese', 'brownies'): 13, ('protein bar', 'cake'): 14, ('grated cheese', 'cake'): 36, ('brownies', 'cereals'): 12, ('olive oil', 'red wine'): 18, ('pepper', 'hot dogs'): 9, ('turkey', 'ground beef'): 69, ('yams', 'tomatoes'): 2, ('burgers', 'champagne'): 29, ('oil', 'pasta'): 4, ('parmesan cheese', 'fromage blanc'): 5, ('yams', 'magazines'): 1, ('cooking oil', 'magazines'): 10, ('fresh tuna', 'mushroom cream sauce'): 4, ('olive oil', 'barbecue sauce'): 2, ('soup', 'butter'): 15, ('protein bar', 'herb & pepper'): 15, ('pasta', 'cereals'): 1, ('cooking oil', 'tomatoes'):
'ground beef'): 165, ('chocolate', 'grated cheese'): 82, ('mineral water', 'french fries'): 253, ('chocolate', 'cake'): 102, ('green tea', 'ground beef'): 111, ('pancakes', 'cake'): 89, ('eggs', 'ground beef'): 150, ('shrimp', 'milk'): 132, ('green tea', 'chicken'): 89, ('mineral water', 'grated cheese'): 131, ('tomatoes', 'ground beef'): 88, ('spaghetti', 'tomatoes'): 157, ('spaghetti', 'grated cheese'): 124, ('olive oil', 'ground beef'): 106, ('green tea', 'eggs'): 191, ('shrimp', 'ground beef'): 86, ('eggs', 'milk'): 231, ('mineral water', 'red wine'): 82, ('low fat yogurt', 'mineral water'): 180, ('burgers', 'milk'): 134, ('eggs', 'turkey'): 146, ('pancakes', 'ground beef'): 109, ('chocolate', 'pancakes'): 149, ('chocolate', 'escalope'): 132, ('french fries', 'escalope'): 123, ('mineral water', 'cereals'): 77, ('shrimp', 'mineral water'): 177, ('milk', 'chicken'): 111, ('shrimp', 'tomatoes'): 84, ('burgers', 'eggs'): 216, ('olive oil', 'chocolate'): 123, ('frozen smoothie', 'eggs'): 83, ('frozen smoothie', 'spaghetti'): 117, ('eggs', 'whole wheat rice'): 82, ('mineral water', 'burgers'): 183, ('eggs', 'spag ...
# L2 Length :  165
# C3 Items :  {('low fat yogurt', 'champagne', 'honey'): 1, ('spaghetti', 'eggs', 'ground beef'): 67, ('milk', 'green tea', 'grated cheese'): 8, ('shrimp', 'tomatoes', 'fresh bread'): 6, ('turkey', 'cake', 'salmon'): 3, ('spaghetti', 'olive oil', 'salmon'): 18, ('cake', 'grated cheese', 'cereals'): 1, ('cooking oil', 'red wine', 'cereals'): 1, ('shrimp', 'salmon', 'honey'): 6, ('turkey', 'chocolate', 'cake'): 10, ('chicken', 'avocado', 'salmon'): 3, ('green tea', 'ground beef', 'cereals'): 13, ('pancakes', 'chocolate', 'frozen smoothie'): 16, ('milk', 'frozen smoothie', 'cereals'): 9, ('shrimp', 'chocolate', 'herb & pepper'): 12, ('green tea', 'escalope', 'frozen smoothie'): 7, ('soup', 'frozen vegetables', 'frozen smoothie'): 4, ('turkey', 'cookies', 'herb & pepper'): 2, ('pancakes', 'chicken', 'burgers'): 9, ('chocolate', 'chicken', 'tomatoes'): 13, ('ground beef', 'avocado', 'grated cheese'): 6, ('eggs', 'avocado', 'cooking oil'): 2, ('tomatoes', 'cooking oil', 'honey'): 4, ('champagne', 'fresh bread', 'frozen smoothie'): 4, ('green tea', 'cake', 'frozen smoothie'): 7, ('pancakes', 'fresh bread', 'frozen smoothie'): 4, ('french fries', 'frozen vegetables', 'cooking oil'): 10, ('pancakes', 'olive oil', 'fresh bread'): 7, ('turkey', 'cake', 'cookies'): 1, ('french fries', 'cake', 'chicken'): 11, ('spaghetti', 'cake', 'low fat yogurt'): 11, ('french fries', 'spaghetti', 'chicken'): 29, ('escalope', 'champagne', 'fresh bread'): 4, ('milk', 'mineral water', 'herb & pepper'): 31, ('whole wheat rice', 'turkey', 'avocado'): 4, ('french fries', 'turkey', 'cereals'): 2, ('soup', 'turkey', 'herb & pepper'): 2, ('mineral water', 'french fries', 'champagne'): 12, ('french fries', 'olive oil', 'grated cheese'): 8, ('cake', 'olive oil', 'grated cheese'): 5, ('pancakes', 'spaghetti', 'champagne'): 9, ('turkey', 'frozen vegetables', 'cake'): 10, ('green tea', 'fresh bread', 'frozen smoothie'): 4, ('pancakes', 'cake', 'frozen smoothie'): 7, ('frozen vegetables', 'cake', 'frozen smoothie'): 7, ('soup', 'tomatoes', 'champagne'): 1, ('pancakes', 'eggs', 'burgers'): 31, ('frozen vegetables', 'avocado', 'cooking oil'): 4, ('ground beef', 'olive oil', 'salmon'): 11, ('avocado', 'fresh bread', 'herb & pepper'): 2, ('eggs', 'fresh bread', 'cereals'): 3, ('ground beef', 'champagne', 'salmon'): 8, ('whole wheat rice', 'turkey', 'tomatoes'): 12, ('soup', 'turkey', 'chicken'): 3, ('green tea', 'tomatoes', 'low fat yogurt'): 5, ('spaghetti', 'ground beef', 'red wine'): 19, ('shrimp', 'avocado', 'olive oil'): 4, ('soup', 'cooking oil', 'burgers'): 3, ('french fries', 'olive oil', 'cookies'): 2, ('green tea', 'spaghetti', 'eggs'): 43, ('green tea', 'turkey', 'salmon'): 5, ('milk', 'herb & pepper', 'cereals'): 8, ('frozen vegetables', 'chicken', 'fresh bread'): 7, ('green tea', 'champagne', 'cooking oil'): 1, ('chicken', 'cookies', 'burgers'): 3, ('frozen vegetables', 'herb & pepper', 'cereals'): 3, ('cake', 'frozen smoothie', 'red wine'): 5, ('chocolate', 'eggs', 'grated cheese'): 19, ('whole wheat rice', 'red wine', 'burgers'): 1, ('green tea', 'french fries', 'eggs'): 53, ('mineral water', 'ground beef', 'herb & pepper'): 50, ('mineral water', 'green tea', 'chocolate'): 52, ('french fries', 'frozen vegetables', 'herb & pepper'): 8, ('eggs', 'fresh bread', 'grated cheese'): 6, ('soup', 'eggs', 'cookies'): 2, ('milk', 'pancakes', 'chicken'): 23, ('pancakes', 'spaghetti', 'honey'): 19, ('mineral water', 'chicken', 'burgers'): 19, ('soup', 'whole wheat rice', 'olive oil'): 4, ('shrimp', 'champagne', 'fresh bread'): 2, ('frozen vegetables', 'tomatoes', 'cookies'): 2, ('milk', 'spaghetti', 'escalope'): 17, ('soup', 'french fries', 'ground beef'): 9, ('shrimp', 'salmon', 'cookies'): 1, ('soup', 'escalope', 'champagne'): 1, ('green tea', 'cake', 'eggs'): 25, ('eggs', 'ground beef', 'salmon'): 16, ('eggs', 'champagne', 'cooking oil'): 2, ('eggs', 'burgers', 'honey'): 3, ('frozen vegetables', 'chicken', 'red wine'): 2, ('milk', 'mineral water', 'frozen smoothie'): 4 ...
# C3 Length :  5207
#
# L3 Items :  {('mineral water', 'spaghetti', 'eggs'): 107, ('chocolate', 'spaghetti', 'eggs'): 79, ('mineral water', 'frozen vegetables', 'spaghetti'): 90, ('mineral water', 'french fries', 'spaghetti'): 76, ('mineral water', 'chocolate', 'spaghetti'): 119, ('mineral water', 'eggs', 'ground beef'): 76, ('mineral water', 'chocolate', 'ground beef'): 82, ('mineral water', 'spaghetti', 'ground beef'): 128, ('milk', 'mineral water', 'eggs'): 98, ('mineral water', 'spaghetti', 'olive oil'): 77, ('milk', 'chocolate', 'spaghetti'): 82, ('mineral water', 'pancakes', 'spaghetti'): 86, ('milk', 'mineral water', 'frozen vegetables'): 83, ('milk', 'mineral water', 'spaghetti'): 118, ('mineral water', 'chocolate', 'eggs'): 101, ('milk', 'mineral water', 'chocolate'): 105, ('milk', 'mineral water', 'ground beef'): 83}
# L3 Length :  17
# C4 Items :  {('french fries', 'ground beef', 'olive oil', 'pancakes'): 2, ('spaghetti', 'chocolate', 'french fries', 'olive oil'): 12, ('spaghetti', 'chocolate', 'ground beef', 'pancakes'): 14, ('spaghetti', 'eggs', 'ground beef', 'olive oil'): 11, ('eggs', 'chocolate', 'french fries', 'olive oil'): 5, ('spaghetti', 'chocolate', 'ground beef', 'milk'): 22, ('mineral water', 'chocolate', 'milk', 'pancakes'): 19, ('chocolate', 'frozen vegetables', 'milk', 'olive oil'): 15, ('eggs', 'chocolate', 'french fries', 'ground beef'): 9, ('chocolate', 'french fries', 'milk', 'olive oil'): 4, ('spaghetti', 'eggs', 'olive oil', 'pancakes'): 10, ('mineral water', 'spaghetti', 'eggs', 'frozen vegetables'): 22, ('mineral water', 'spaghetti', 'frozen vegetables', 'french fries'): 16, ('mineral water', 'eggs', 'chocolate', 'ground beef'): 30, ('mineral water', 'chocolate', 'olive oil', 'pancakes'): 13, ('eggs', 'chocolate', 'milk', 'olive oil'): 10, ('mineral water', 'eggs', 'ground beef', 'milk'): 25, ('mineral water', 'spaghetti', 'chocolate', 'frozen vegetables'): 31, ('mineral water', 'chocolate', 'milk', 'olive oil'): 19, ('mineral water', 'ground beef', 'milk', 'pancakes'): 15, ('chocolate', 'ground beef', 'milk', 'pancakes'): 9, ('mineral water', 'eggs', 'french fries', 'pancakes'): 7, ('mineral water', 'french fries', 'ground beef', 'olive oil'): 4, ('spaghetti', 'eggs', 'frozen vegetables', 'ground beef'): 18, ('mineral water', 'eggs', 'chocolate', 'pancakes'): 17, ('mineral water', 'eggs', 'milk', 'olive oil'): 20, ('spaghetti', 'eggs', 'chocolate', 'french fries'): 22, ('spaghetti', 'eggs', 'frozen vegetables', 'olive oil'): 11, ('frozen vegetables', 'ground beef', 'milk', 'pancakes'): 5, ('mineral water', 'eggs', 'french fries', 'milk'): 16, ('spaghetti', 'french fries', 'ground beef', 'milk'): 11, ('mineral water', 'spaghetti', 'eggs', 'pancakes'): 18, ('mineral water', 'eggs', 'olive oil', 'pancakes'): 6, ('mineral water', 'spaghetti', 'frozen vegetables', 'pancakes'): 18, ('mineral water', 'eggs', 'frozen vegetables', 'olive oil'): 13, ('mineral water', 'french fries', 'milk', 'olive oil'): 11, ('spaghetti', 'eggs', 'milk', 'olive oil'): 12, ('spaghetti', 'french fries', 'ground beef', 'pancakes'): 9, ('mineral water', 'french fries', 'ground beef', 'pancakes'): 8, ('mineral water', 'spaghetti', 'ground beef', 'milk'): 33, ('mineral water', 'frozen vegetables', 'milk', 'olive oil'): 25, ('chocolate', 'french fries', 'ground beef', 'olive oil'): 1, ('mineral water', 'spaghetti', 'eggs', 'olive oil'): 18, ('mineral water', 'spaghetti', 'ground beef', 'pancakes'): 23, ('mineral water', 'chocolate', 'frozen vegetables', 'olive oil'): 21, ('mineral water', 'spaghetti', 'eggs', 'chocolate'): 34, ('mineral water', 'french fries', 'milk', 'pancakes'): 14, ('mineral water', 'spaghetti', 'chocolate', 'milk'): 37, ('eggs', 'chocolate', 'ground beef', 'olive oil'): 8, ('mineral water', 'spaghetti', 'french fries', 'ground beef'): 21, ('eggs', 'chocolate', 'frozen vegetables', 'french fries'): 10, ('mineral water', 'spaghetti', 'chocolate', 'pancakes'): 28, ('mineral water', 'chocolate', 'frozen vegetables', 'milk'): 30, ('spaghetti', 'frozen vegetables', 'ground beef', 'milk'): 23, ('eggs', 'chocolate', 'ground beef', 'milk'): 14, ('mineral water', 'frozen vegetables', 'ground beef', 'pancakes'): 11, ('spaghetti', 'eggs', 'chocolate', 'ground beef'): 23, ('spaghetti', 'eggs', 'chocolate', 'olive oil'): 11, ('mineral water', 'spaghetti', 'french fries', 'pancakes'): 19, ('chocolate', 'frozen vegetables', 'ground beef', 'pancakes'): 6, ('chocolate', 'ground beef', 'milk', 'olive oil'): 13, ('mineral water', 'spaghetti', 'chocolate', 'ground beef'): 30, ('eggs', 'ground beef', 'milk', 'pancakes'): 4, ('mineral water', 'eggs', 'chocolate', 'olive oil'): 18, ('spaghetti', 'eggs', 'french fries', 'milk'): 20, ('mineral water', 'chocolate', 'french fries', 'ground beef'): 9, ('spaghetti', 'chocolate', 'frozen vegetables', 'olive oil'): 16, ('chocol ...
# C4 Length :  210
#
# L4 Items :  {}
# L4 Length :  0
#
# ['ground beef'] -> ['mineral water'] (0.41655359565807326)
# ['salmon'] -> ['mineral water'] (0.4012539184952978)
# ['olive oil'] -> ['mineral water'] (0.4190283400809717)
# ['soup'] -> ['mineral water'] (0.45646437994722955)
# ['cereals'] -> ['mineral water'] (0.39896373056994816)
# ['cooking oil'] -> ['mineral water'] (0.39425587467362927)
# ['ground beef'] -> ['spaghetti'] (0.3989145183175034)
# ['frozen vegetables', 'spaghetti'] -> ['mineral water'] (0.430622009569378)
# ['eggs', 'ground beef'] -> ['mineral water'] (0.5066666666666667)
# ['chocolate', 'ground beef'] -> ['mineral water'] (0.47398843930635837)
# ['mineral water', 'ground beef'] -> ['spaghetti'] (0.4169381107491857)
# ['spaghetti', 'ground beef'] -> ['mineral water'] (0.43537414965986393)
# ['milk', 'frozen vegetables'] -> ['mineral water'] (0.4689265536723164)
# ['milk', 'spaghetti'] -> ['mineral water'] (0.44360902255639095)
# ['milk', 'chocolate'] -> ['mineral water'] (0.43568464730290457)
# ['milk', 'ground beef'] -> ['mineral water'] (0.503030303030303)
# 16 Rules generated

# %% [markdown]
# <div class="alert alert-block alert-info">Thank You<br>Regards<br>Dimple K Sai & Shripriya Bhat<br>JSS Science and Technology University</div>
